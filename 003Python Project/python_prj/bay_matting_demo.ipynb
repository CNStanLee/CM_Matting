# %%
# ------------- import external libs  ----------------- #
import cv2
import numpy as np
from matplotlib import pyplot as plt
import time
from memory_profiler import profile
import psutil
import os
import tracemalloc
# ------------- import user libs  --------------------- #
import bay_matting_fun as bm

# %%
# general
# low
# image_path = 'Dataset/input_training_lowres/GT03.png'
# trimap_path = 'Dataset/trimap_training_lowres/GT03.png'
# alpha_map_ground_truth_path = 'Dataset/gt_training_lowres/GT03.png'
# high
image_path = 'Dataset/input_training_highres/GT03.png'
trimap_path = 'Dataset/trimap_training_highres/GT03.png'
alpha_map_ground_truth_path = 'Dataset/gt_training_highres/GT03.png'
# constant
alpha_map_path = 'AlphaMap.png'

# %%
# ------------- complexity estimation begin ----------- #
tracemalloc.start()
start_time = time.time()
# ------------- estimate function begin --------------- #
AlphaMap = bm.bayesian_matting(image_path, trimap_path, oriVar=8, Iteration=10)
# ------------- estimate function  end  --------------- #
# calculate memory consumption
snapshot = tracemalloc.take_snapshot()
stats = snapshot.statistics('lineno')
total_memory = sum(stat.size for stat in stats)
print(f"Total memory usage: {total_memory} bytes")
tracemalloc.stop()
# calculate time consumption
elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# ------------- complexity estimation end ------------- #


# save alpha map output

cv2.imwrite(alpha_map_path, AlphaMap)
print("Alpha Map saved to:", alpha_map_path)

# display alpha map
plt.figure(figsize=(6, 6))
plt.imshow(AlphaMap, cmap='gray')
plt.title("Alpha Map")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 start_time = time.time()
#       4 # ------------- estimate function begin --------------- #
# ----> 5 AlphaMap = bm.bayesian_matting(image_path, trimap_path, oriVar=8, Iteration=10)
#       6 # ------------- estimate function  end  --------------- #
#       7 # calculate memory consumption
#       8 snapshot = tracemalloc.take_snapshot()
#
# File ~/prj/CM_Matting/CM_Matting/003Python Project/python_prj/bay_matting_fun.py:153, in bayesian_matting(image_path, trimap_path, oriVar, Iteration)
#     150 backImg = np.where(triMap_expanded <= BThreshold, oriImg, 0).astype(float)
#     151 unknownImg = np.where((triMap_expanded > BThreshold) & (triMap_expanded < FThreshold), oriImg, 0).astype(float)
# --> 153 Fmean, Bmean, coF, coB = compute_mean_cov(frontImg, backImg, unknownImg, width, height)
#     154 unknownAlpha, _, _ = update_alpha(unknownImg, triMap, Fmean, Bmean, coF, coB, oriVar, Iteration, width, height)
#     156 AlphaMap = (unknownAlpha * 255).astype(np.uint8)
#
# File ~/prj/CM_Matting/CM_Matting/003Python Project/python_prj/bay_matting_fun.py:56, in compute_mean_cov(frontImg, backImg, unknownImg, width, height)
#      54         if np.any(backImg[a, b, :]):
#      55             shiftB = backImg[a, b, :] - Bmean
# ---> 56             coB += np.outer(shiftB, shiftB)
#      57             NB += 1
#      58 coF /= NF
#
# File <__array_function__ internals>:200, in outer(*args, **kwargs)
#
# File ~/anaconda3/envs/dl/lib/python3.8/site-packages/numpy/core/numeric.py:943, in outer(a, b, out)
#     941 a = asarray(a)
#     942 b = asarray(b)
# --> 943 return multiply(a.ravel()[:, newaxis], b.ravel()[newaxis, :], out)
#
# KeyboardInterrupt:

# %%
# ------------- complexity estimation begin ----------- #
tracemalloc.start()
start_time = time.time()
# ------------- estimate function begin --------------- #
bm.show_foreground_with_threshold(image_path, trimap_path, threshold=0.96)
# ------------- estimate function  end  --------------- #
# calculate memory consumption
snapshot = tracemalloc.take_snapshot()
stats = snapshot.statistics('lineno')
total_memory = sum(stat.size for stat in stats)
print(f"Total memory usage: {total_memory} bytes")
tracemalloc.stop()
# calculate time consumption
elapsed_time = time.time() - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# ------------- complexity estimation end ------------- #
# Out:
# Total memory usage: 17017825 bytes
# Elapsed time: 0.4930388927459717 seconds

# %%
# accuracy estimation
# MSE estimation


# Calculate MSE
mse_value = bm.calculate_alpha_mse(alpha_map_path, alpha_map_ground_truth_path)
print("Mean Squared Error (MSE):", mse_value)
# Out:
# Mean Squared Error (MSE): 0.049846344

# %%
# PSNR estimation
# Load the images


# Calculate PSNR
psnr_value = bm.calculate_psnr(alpha_map_path, alpha_map_ground_truth_path)
print("PSNR:", psnr_value)
# Out:
# PSNR: 13.023666923340071
